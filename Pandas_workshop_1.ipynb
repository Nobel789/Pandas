# %%
#pandas basics for data analysis

# %%
import pandas as pd

# %%
#assigning the ditionary to dataframe structure
data = {
    'Name': ['John', 'Emma', 'Peter', 'Emily', 'Michael', 'Sophia', 'Daniel', 'Olivia'],
    'Age': [25, 30, 28, 32, 27, 35, 29, 31],
    'Country': ['USA', 'UK', 'Canada', 'Australia', 'USA', 'UK', 'Canada', 'Australia'],
    'Salary': [50000, 60000, 55000, 70000, 48000, 62000, 58000, 69000]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age    Country  Salary
# 0     John   25        USA   50000
# 1     Emma   30         UK   60000
# 2    Peter   28     Canada   55000
# 3    Emily   32  Australia   70000
# 4  Michael   27        USA   48000
# 5   Sophia   35         UK   62000
# 6   Daniel   29     Canada   58000
# 7   Olivia   31  Australia   69000

# %%
#removing duplicate value
df_no_duplicates = df.drop_duplicates()

# %%
#each column you can treat as series , you can assign new value by specifying column location and name
series=pd.Series([8,9],index=["tina","lima"],name="Name")
series
# Out:
# tina    8
# lima    9
# Name: Name, dtype: int64

# %%
df
# Out:
#       Name  Age    Country  Salary
# 0     John   25        USA   50000
# 1     Emma   30         UK   60000
# 2    Peter   28     Canada   55000
# 3    Emily   32  Australia   70000
# 4  Michael   27        USA   48000
# 5   Sophia   35         UK   62000
# 6   Daniel   29     Canada   58000
# 7   Olivia   31  Australia   69000

# %%
df.head()
# Out:
#       Name  Age    Country  Salary
# 0     John   25        USA   50000
# 1     Emma   30         UK   60000
# 2    Peter   28     Canada   55000
# 3    Emily   32  Australia   70000
# 4  Michael   27        USA   48000

# %%
df.tail()
# Out:
#       Name  Age    Country  Salary
# 3    Emily   32  Australia   70000
# 4  Michael   27        USA   48000
# 5   Sophia   35         UK   62000
# 6   Daniel   29     Canada   58000
# 7   Olivia   31  Australia   69000

# %%
df.describe()
# Out:
#              Age        Salary
# count   8.000000      8.000000
# mean   29.625000  59000.000000
# std     3.113909   8017.837257
# min    25.000000  48000.000000
# 25%    27.750000  53750.000000
# 50%    29.500000  59000.000000
# 75%    31.250000  63750.000000
# max    35.000000  70000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     8 non-null      object
#  1   Age      8 non-null      int64
#  2   Country  8 non-null      object
#  3   Salary   8 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
#see a single column data
x=df[["Salary"]]
x
# Out:
#    Salary
# 0   50000
# 1   60000
# 2   55000
# 3   70000
# 4   48000
# 5   62000
# 6   58000
# 7   69000

# %%
#you can also combine more than one column and assign them to a variable
Y=df[["Name","Age","Country"]]
Y
# Out:
#       Name  Age    Country
# 0     John   25        USA
# 1     Emma   30         UK
# 2    Peter   28     Canada
# 3    Emily   32  Australia
# 4  Michael   27        USA
# 5   Sophia   35         UK
# 6   Daniel   29     Canada
# 7   Olivia   31  Australia

# %%
df["Age"].unique()
# Out:
# array([25, 30, 28, 32, 27, 35, 29, 31])

# %%
df["Age"].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Age, dtype: bool

# %%
#Filtering the data with comparison operator

df["Age"]<35
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# Name: Age, dtype: bool

# %%
df["Salary"]>30000
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# Name: Salary, dtype: bool

# %%
#slicing with loc method(name or labelof row and column)and iloc method(number or indexing of row and column)
df.iloc[0:3]
# Out:
#     Name  Age Country  Salary
# 0   John   25     USA   50000
# 1   Emma   30      UK   60000
# 2  Peter   28  Canada   55000

# %%
df
# Out:
#       Name  Age    Country  Salary
# 0     John   25        USA   50000
# 1     Emma   30         UK   60000
# 2    Peter   28     Canada   55000
# 3    Emily   32  Australia   70000
# 4  Michael   27        USA   48000
# 5   Sophia   35         UK   62000
# 6   Daniel   29     Canada   58000
# 7   Olivia   31  Australia   69000

# %%
#setting the new index from anouther column
df1=df.set_index("Name")
df1
# Out:
#          Age    Country  Salary
# Name
# John      25        USA   50000
# Emma      30         UK   60000
# Peter     28     Canada   55000
# Emily     32  Australia   70000
# Michael   27        USA   48000
# Sophia    35         UK   62000
# Daniel    29     Canada   58000
# Olivia    31  Australia   69000

# %%
#now specifying the location for slicing by name and loc function
df1.loc["Daniel","Salary"]
# Out:
# 58000
